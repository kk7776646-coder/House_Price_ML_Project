# %% [markdown]
# # House Price Prediction Regression Project

# %% [markdown]
# ## Project Aim

# %% [raw]
# This project predicts house prices using supervised machine learning regression techniques. By analyzing features such as location, size, number of rooms, and other property attributes, the model estimates the expected market price, helping buyers and sellers make informed decisions.

# %% [markdown]
# ## Load Modules & Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import calendar

from pandas.api.types import CategoricalDtype
from sklearn.preprocessing import StandardScaler

# %%
train_data_path = r"C:\House_Price_ML_Project\Data\train.csv"
test_data_path = r"C:\House_Price_ML_Project\Data\test.csv"

df_train = pd.read_csv(train_data_path)
df_test = pd.read_csv(test_data_path )

print("Shape of df_train =",df_train.shape)
print("Shape of df_test =",df_test.shape)
# Out:
# Shape of df_train = (1460, 81)
# Shape of df_test = (1459, 80)

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df_train.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
pd.set_option("display.max_columns",None)
pd.set_option("display.max_rows",None)

# %%
df_test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Know Your Data

# %% [raw]
# ## Will use this feature while converting into numerical format / Encoding
# Neighborhooh
# OverallQual
# OverallCond
# YearBuilt
# Foundation *
# Electrical
# KitchenQual
# GarageType
# GarageFinish
# Fence

# %% [markdown]
# ## Data Integration

# %%
df = pd.concat([df_train,df_test])
print("Shape of Integrated Data/DF:",df.shape)
# Out:
# Shape of Integrated Data/DF: (2919, 81)

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 1         Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 2         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 3         Lvl    AllPub    Corner       Gtl      Crawfor       Norm
# 4         Lvl    AllPub       FR2       Gtl      NoRidge       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 1454         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1455         Lvl    AllPub    Inside       Gtl      MeadowV       Norm
# 1456         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1457         Lvl    AllPub    Inside       Gtl      Mitchel       Norm
# 1458         Lvl    AllPub    Inside       Mod      Mitchel       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %% [markdown]
# ## Get The Brief Information of Dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 0 to 1458
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             2919 non-null   int64
#  1   MSSubClass     2919 non-null   int64
#  2   MSZoning       2915 non-null   object
#  3   LotFrontage    2433 non-null   float64
#  4   LotArea        2919 non-null   int64
#  5   Street         2919 non-null   object
#  6   Alley          198 non-null    object
#  7   LotShape       2919 non-null   object
#  8   LandContour    2919 non-null   object
#  9   Utilities      2917 non-null   object
#  10  LotConfig      2919 non-null   object
#  11  LandSlope      2919 non-null   object
#  12  Neighborhood   2919 non-null   object
#  13  Condition1     2919 non-null   object
#  14  Condition2     2919 non-null   object
#  15  BldgType       2919 non-null   object
#  16  HouseStyle     2919 non-null   object
# ...

# %% [raw]
# # Most null value Feature
# Alley
# FireplaceQu
# PooQC
# Fence
# MiscFeature

# %%
int_features = df.select_dtypes(include=["int64"]).columns
print("Total Number of Integer Features :",int_features.shape[0])
print("Integer Features Name:",int_features.tolist())
# Out:
# Total Number of Integer Features : 26
# Integer Features Name: ['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']

# %%
float_features = df.select_dtypes(include=["float64"]).columns
print("Total Number of Floating Features :",float_features.shape[0])
print("Floating Features Name:",float_features.tolist())
# Out:
# Total Number of Floating Features : 12
# Floating Features Name: ['LotFrontage', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'SalePrice']

# %%
cat_features = df.select_dtypes(include=["object"]).columns
print("Total Number of Categorical Features :",cat_features.shape[0])
print("Categorical Features Name:",cat_features.tolist())
# Out:
# Total Number of Categorical Features : 43
# Categorical Features Name: ['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2', 'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual', 'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature', 'SaleType', 'SaleCondition']

# %% [markdown]
# ## Get The Statical Information of Numerical Features

# %%
df.describe()
# Out:
#                 Id   MSSubClass  LotFrontage        LotArea  OverallQual  \
# count  2919.000000  2919.000000  2433.000000    2919.000000  2919.000000
# mean   1460.000000    57.137718    69.305795   10168.114080     6.089072
# std     842.787043    42.517628    23.344905    7886.996359     1.409947
# min       1.000000    20.000000    21.000000    1300.000000     1.000000
# 25%     730.500000    20.000000    59.000000    7478.000000     5.000000
# 50%    1460.000000    50.000000    68.000000    9453.000000     6.000000
# 75%    2189.500000    70.000000    80.000000   11570.000000     7.000000
# max    2919.000000   190.000000   313.000000  215245.000000    10.000000
#
#        OverallCond    YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1  \
# count  2919.000000  2919.000000   2919.000000  2896.000000  2918.000000
# mean      5.564577  1971.312778   1984.264474   102.201312   441.423235
# std       1.113131    30.291442     20.894344   179.334253   455.610826
# ...

# %%
df.describe().shape
# Out:
# (8, 38)

# %% [markdown]
# ## Visualise null & Missing Values

# %%
plt.figure(figsize=(16,9))
sns.heatmap(df.isnull())

plt.savefig(r"C:\House_Price_ML_Project\EDA_img\heatmap_DF_of_null_values.png")
plt.show()

# %% [markdown]
# ## Get The Null Value Percentage For Every Feature

# %%
# Set Index as Id Column
df = df.set_index("Id")

# %%
null_count = df.isnull().sum()
null_count
# Out:
# MSSubClass          0
# MSZoning            4
# LotFrontage       486
# LotArea             0
# Street              0
# Alley            2721
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType       1766
# MasVnrArea         23
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           81
# BsmtCond           82
# BsmtExposure       82
# BsmtFinType1       79
# BsmtFinSF1          1
# BsmtFinType2       80
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %%
null_percent = df.isnull().sum()/df.shape[0]*100
null_percent
# Out:
# MSSubClass        0.000000
# MSZoning          0.137033
# LotFrontage      16.649538
# LotArea           0.000000
# Street            0.000000
# Alley            93.216855
# LotShape          0.000000
# LandContour       0.000000
# Utilities         0.068517
# LotConfig         0.000000
# LandSlope         0.000000
# Neighborhood      0.000000
# Condition1        0.000000
# Condition2        0.000000
# BldgType          0.000000
# HouseStyle        0.000000
# OverallQual       0.000000
# OverallCond       0.000000
# YearBuilt         0.000000
# YearRemodAdd      0.000000
# RoofStyle         0.000000
# RoofMatl          0.000000
# Exterior1st       0.034258
# Exterior2nd       0.034258
# MasVnrType       60.500171
# MasVnrArea        0.787941
# ExterQual         0.000000
# ExterCond         0.000000
# Foundation        0.000000
# BsmtQual          2.774923
# BsmtCond          2.809181
# BsmtExposure      2.809181
# BsmtFinType1      2.706406
# BsmtFinSF1        0.034258
# ...

# %% [markdown]
# ## Drop Column & Features
# As per observation, we will not drop any feature from dataset

# %%
""" As per domain knowledge we will not drop those features, instead None value we will add constant value NA """

miss_value_50_perc = null_percent[null_percent > 50]
miss_value_50_perc
# Out:
# Alley          93.216855
# MasVnrType     60.500171
# PoolQC         99.657417
# Fence          80.438506
# MiscFeature    96.402878
# dtype: float64

# %%
df["Alley"].value_counts()
# Out:
# Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64

# %%
""" As per domain knowledge we will not drop FireplaceQu features, instead None value we will add constant value NA """

miss_value_50_20_perc = null_percent[(null_percent>20) & (null_percent<51)]
miss_value_50_20_perc
# Out:
# FireplaceQu    48.646797
# SalePrice      49.982871
# dtype: float64

# %%
miss_value_5_20_perc = null_percent[(null_percent>5) & (null_percent<21)]
miss_value_5_20_perc
# Out:
# LotFrontage     16.649538
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# dtype: float64

# %%
df["LotFrontage"].value_counts().head()
# Out:
# LotFrontage
# 60.0    276
# 80.0    137
# 70.0    133
# 50.0    117
# 75.0    105
# Name: count, dtype: int64

# %%
sns.heatmap(df[miss_value_5_20_perc.keys()].isnull())
# Out:
# <Axes: ylabel='Id'>

# %% [markdown]
# ## Missing Value Imputation

# %%
missing_value_feat = null_percent[null_percent > 0]
print("Total missing value features :",len(missing_value_feat))
# Out:
# Total missing value features : 35

# %%
missing_value_feat
# Out:
# MSZoning         0.137033
# LotFrontage     16.649538
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# MasVnrArea       0.787941
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinSF1       0.034258
# BsmtFinType2     2.740665
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# Electrical       0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageYrBlt      5.447071
# GarageFinish     5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# SalePrice       49.982871
# dtype: float64

# %%
cat_na_feat = missing_value_feat[missing_value_feat.keys().isin(cat_features)]
print("Total number of missing categorical features :",len(cat_na_feat))
# Out:
# Total number of missing categorical features : 23

# %%
cat_na_feat
# Out:
# MSZoning         0.137033
# Alley           93.216855
# Utilities        0.068517
# Exterior1st      0.034258
# Exterior2nd      0.034258
# MasVnrType      60.500171
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
# Electrical       0.034258
# KitchenQual      0.034258
# Functional       0.068517
# FireplaceQu     48.646797
# GarageType       5.378554
# GarageFinish     5.447071
# GarageQual       5.447071
# GarageCond       5.447071
# PoolQC          99.657417
# Fence           80.438506
# MiscFeature     96.402878
# SaleType         0.034258
# dtype: float64

# %% [raw]
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
#
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517

# %%
int_na_feat = missing_value_feat[missing_value_feat.keys().isin(int_features)]
print("Total number of missing integer features :",len(int_na_feat))
# Out:
# Total number of missing integer features : 0

# %%
int_na_feat
# Out:
# Series([], dtype: float64)

# %%
float_na_feat = missing_value_feat[missing_value_feat.keys().isin(float_features)]
print("Total number of missing float features :",len(float_na_feat))
# Out:
# Total number of missing float features : 12

# %%
float_na_feat
# Out:
# LotFrontage     16.649538
# MasVnrArea       0.787941
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517
# GarageYrBlt      5.447071
# GarageCars       0.034258
# GarageArea       0.034258
# SalePrice       49.982871
# dtype: float64

# %% [markdown]
# ## Handling MSZoning = 0.137033

# %%
df["MSZoning"].value_counts()
# Out:
# MSZoning
# RL         2265
# RM          460
# FV          139
# RH           26
# C (all)      25
# Name: count, dtype: int64

# %%
colors = ["blue", "yellow", "green", "red", "purple"]
sns.countplot(data=df, x="MSZoning", hue="MSZoning", palette=colors, legend=False)
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %%
### backup of original data 
df_mvi = df.copy()
df_mvi.shape
# Out:
# (2919, 80)

# %%
mszoning_mode = df_mvi["MSZoning"].mode()[0]
df_mvi["MSZoning"] = df_mvi["MSZoning"].fillna(mszoning_mode)
print(df_mvi["MSZoning"].isnull().sum())
# Out:
# 0

# %%
colors = ["blue", "yellow", "green", "red", "purple"]
sns.countplot(data=df_mvi, x="MSZoning", hue="MSZoning", palette=colors, legend=False)
# Out:
# <Axes: xlabel='MSZoning', ylabel='count'>

# %%
def oldNewCountPlot(df, df_new, feature):
    plt.figure(figsize=(12, 5))

    colors = ["blue", "yellow", "green", "red", "purple"]

    # Old Data
    plt.subplot(121)

    old_categories = df[feature].nunique()
    sns.countplot(data=df, x=feature, hue=feature, palette=colors[:old_categories], legend=False)

    plt.title("Old Data Distribution")

    # New Data
    plt.subplot(122)

    new_categories = df_new[feature].nunique()
    sns.countplot(data=df_new, x=feature, hue=feature, palette=colors[:new_categories], legend=False)

    plt.title("New Data Distribution")
    plt.show()

# %%
oldNewCountPlot(df, df_mvi, "MSZoning")

# %% [markdown]
# ## Handling Alley = 93.216855

# %%
df["Alley"].value_counts()
# Out:
# Alley
# Grvl    120
# Pave     78
# Name: count, dtype: int64

# %%
alley_cont = "NA"

df_mvi["Alley"] = df_mvi["Alley"].fillna(alley_cont)

print(df_mvi["Alley"].isnull().sum())
# Out:
# 0

# %%
oldNewCountPlot(df, df_mvi, "Alley")

# %% [markdown]
# ## Handling LotFrontage = 16.649538

# %%
def boxHistPlot(df, figsize=(16,5)):
    plt.figure(figsize=figsize)

    plt.subplot(121)
    sns.boxplot(x=df)

    plt.subplot(122)
    sns.distplot(x=df)

    plt.show()

# %%
boxHistPlot(df["LotFrontage"])
# Out:
# C:\Users\KALAMUDDIN\AppData\Local\Temp\ipykernel_13752\2755286714.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df)

# %%
lotfrontage_mean = df["LotFrontage"].mean()
df_mvi["LotFrontage"] = df_mvi["LotFrontage"].fillna(lotfrontage_mean)
print(df_mvi["LotFrontage"].isnull().sum())
# Out:
# 0

# %%
def oldNewBoxHistPlot(df, df_new, feature, figsize=(16,10)):
    plt.figure(figsize=figsize)
    
    plt.subplot(221)
    sns.boxplot(x=df[feature])
    plt.title("Old Data Distribution")
    
    plt.subplot(222)
    sns.distplot(x=df[feature])
    plt.title("Old Data Distribution")
    
    plt.subplot(223)
    sns.boxplot(x=df_new[feature])
    plt.title("New Data Distribution")
    
    plt.subplot(224)
    sns.distplot(x=df_new[feature])
    plt.title("New Data Distribution")

# %%
oldNewBoxHistPlot(df, df_mvi, "LotFrontage")
# Out:
# C:\Users\KALAMUDDIN\AppData\Local\Temp\ipykernel_13752\3484064346.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df[feature])
# C:\Users\KALAMUDDIN\AppData\Local\Temp\ipykernel_13752\3484064346.py:17: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# ## Handling Utilities = 0.068517

# %%
df["Utilities"].value_counts()
# Out:
# Utilities
# AllPub    2916
# NoSeWa       1
# Name: count, dtype: int64

# %%
utilities_mode = df_mvi["Utilities"].mode()[0]
df_mvi["Utilities"] = df_mvi["Utilities"].fillna(utilities_mode)
print(df_mvi["Utilities"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Handling Exterior1st = 0.034258 & Exterior2nd = 0.034258

# %%
df["Exterior1st"].value_counts()
# Out:
# Exterior1st
# VinylSd    1025
# MetalSd     450
# HdBoard     442
# Wd Sdng     411
# Plywood     221
# CemntBd     126
# BrkFace      87
# WdShing      56
# AsbShng      44
# Stucco       43
# BrkComm       6
# AsphShn       2
# Stone         2
# CBlock        2
# ImStucc       1
# Name: count, dtype: int64

# %%
df["Exterior2nd"].value_counts()
# Out:
# Exterior2nd
# VinylSd    1014
# MetalSd     447
# HdBoard     406
# Wd Sdng     391
# Plywood     270
# CmentBd     126
# Wd Shng      81
# BrkFace      47
# Stucco       47
# AsbShng      38
# Brk Cmn      22
# ImStucc      15
# Stone         6
# AsphShn       4
# CBlock        3
# Other         1
# Name: count, dtype: int64

# %%
exterior1st_mode = df_mvi["Exterior1st"].mode()[0]
exterior2nd_mode = df_mvi["Exterior2nd"].mode()[0]
df_mvi["Exterior1st"] = df_mvi["Exterior1st"].fillna(exterior1st_mode)
df_mvi["Exterior2nd"] = df_mvi["Exterior2nd"].fillna(exterior2nd_mode)
print("E1st is null :",df_mvi["Exterior1st"].isnull().sum())
print("E2nd is null :",df_mvi["Exterior2nd"].isnull().sum())
# Out:
# E1st is null : 0
# E2nd is null : 0

# %% [markdown]
# ## Handling MasVnrType = 60.500171 & MasVnrArea = 0.787941

# %%
print(df['MasVnrType'].value_counts(dropna=False))
# Out:
# MasVnrType
# NaN        1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: count, dtype: int64

# %%
print(df['MasVnrArea'].describe())
# Out:
# count    2896.000000
# mean      102.201312
# std       179.334253
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%       164.000000
# max      1600.000000
# Name: MasVnrArea, dtype: float64

# %%
print(df[['MasVnrType', 'MasVnrArea']].isnull().sum())
# Out:
# MasVnrType    1766
# MasVnrArea      23
# dtype: int64

# %%
print(pd.crosstab(df['MasVnrType'], df['MasVnrArea'].isnull()))
# Out:
# MasVnrArea  False
# MasVnrType
# BrkCmn         25
# BrkFace       879
# Stone         249

# %%
df.loc[df['MasVnrType'].isnull(), 'MasVnrArea'].value_counts().head(20)
# Out:
# MasVnrArea
# 0.0      1735
# 1.0         3
# 288.0       1
# 344.0       1
# 312.0       1
# 285.0       1
# 198.0       1
# Name: count, dtype: int64

# %%
df[df['MasVnrArea'].isnull()][['MasVnrType', 'MasVnrArea']]
# Out:
#      MasVnrType  MasVnrArea
# Id
# 235         NaN         NaN
# 530         NaN         NaN
# 651         NaN         NaN
# 937         NaN         NaN
# 974         NaN         NaN
# 978         NaN         NaN
# 1244        NaN         NaN
# 1279        NaN         NaN
# 1692        NaN         NaN
# 1707        NaN         NaN
# 1883        NaN         NaN
# 1993        NaN         NaN
# 2005        NaN         NaN
# 2042        NaN         NaN
# 2312        NaN         NaN
# 2326        NaN         NaN
# 2341        NaN         NaN
# 2350        NaN         NaN
# 2369        NaN         NaN
# 2593        NaN         NaN
# 2658        NaN         NaN
# 2687        NaN         NaN
# 2863        NaN         NaN

# %%
df['MasVnrArea'] = df['MasVnrArea'].fillna(0)
df['MasVnrType'] = df['MasVnrType'].fillna('None')

# %%
df[['MasVnrType', 'MasVnrArea']].isnull().sum()
# Out:
# MasVnrType    0
# MasVnrArea    0
# dtype: int64

# %%
sns.heatmap(df[["MasVnrType" ,"MasVnrArea"]].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
df["MasVnrType"].value_counts()
# Out:
# MasVnrType
# None       1766
# BrkFace     879
# Stone       249
# BrkCmn       25
# Name: count, dtype: int64

# %%
masVnrtype_mode = df_mvi["MasVnrType"].mode()[0]
df_mvi["MasVnrType"] = df_mvi["MasVnrType"].fillna(masVnrtype_mode)
print(df_mvi["MasVnrType"].isnull().sum())
# Out:
# 0

# %%
boxHistPlot(df["MasVnrArea"])
# Out:
# C:\Users\KALAMUDDIN\AppData\Local\Temp\ipykernel_13752\2755286714.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df)

# %%
masvnrarea_cont = 0
df_mvi["MasVnrArea"] = df_mvi["MasVnrArea"].fillna(masvnrarea_cont)
print(df_mvi["MasVnrArea"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Handling Bsmt Features

# %% [raw]
# """cat_bsmt_feat
# BsmtQual         2.774923
# BsmtCond         2.809181
# BsmtExposure     2.809181
# BsmtFinType1     2.706406
# BsmtFinType2     2.740665
#
# num_bsmt_feat
# BsmtFinSF1       0.034258
# BsmtFinSF2       0.034258
# BsmtUnfSF        0.034258
# TotalBsmtSF      0.034258
# BsmtFullBath     0.068517
# BsmtHalfBath     0.068517"""

# %%
cat_bsmt_feat =["BsmtQual",
"BsmtCond",
"BsmtExposure",    
"BsmtFinType1", 
"BsmtFinType2"] 

num_bsmt_feat =["BsmtFinSF1",       
"BsmtFinSF2",      
"BsmtUnfSF",       
"TotalBsmtSF",      
"BsmtFullBath",    
"BsmtHalfBath"]

# %%
sns.heatmap(df[cat_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
for feat in cat_bsmt_feat:
    print(f"Value count of {feat}: {df[feat].value_counts()}")
# Out:
# Value count of BsmtQual: BsmtQual
# TA    1283
# Gd    1209
# Ex     258
# Fa      88
# Name: count, dtype: int64
# Value count of BsmtCond: BsmtCond
# TA    2606
# Gd     122
# Fa     104
# Po       5
# Name: count, dtype: int64
# Value count of BsmtExposure: BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# Name: count, dtype: int64
# Value count of BsmtFinType1: BsmtFinType1
# Unf    851
# GLQ    849
# ALQ    429
# Rec    288
# BLQ    269
# LwQ    154
# Name: count, dtype: int64
# Value count of BsmtFinType2: BsmtFinType2
# Unf    2493
# Rec     105
# LwQ      87
# BLQ      68
# ALQ      52
# GLQ      34
# Name: count, dtype: int64

# %%
bsmt_cont = "NA"

for feat in cat_bsmt_feat:
    df_mvi[feat] = df_mvi[feat].replace(np.nan, bsmt_cont)

# %%
df_mvi[cat_bsmt_feat].isnull().sum()
# Out:
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# dtype: int64

# %%
sns.heatmap(df[num_bsmt_feat].isnull())
# Out:
# <Axes: ylabel='Id'>

# %%
df_bsmt = df[cat_bsmt_feat + num_bsmt_feat]
df_bsmt[df_bsmt.isnull().any(axis=1)]
# Out:
#      BsmtQual BsmtCond BsmtExposure BsmtFinType1 BsmtFinType2  BsmtFinSF1  \
# Id
# 18        NaN      NaN          NaN          NaN          NaN         0.0
# 40        NaN      NaN          NaN          NaN          NaN         0.0
# 91        NaN      NaN          NaN          NaN          NaN         0.0
# 103       NaN      NaN          NaN          NaN          NaN         0.0
# 157       NaN      NaN          NaN          NaN          NaN         0.0
# 183       NaN      NaN          NaN          NaN          NaN         0.0
# 260       NaN      NaN          NaN          NaN          NaN         0.0
# 333        Gd       TA           No          GLQ          NaN      1124.0
# 343       NaN      NaN          NaN          NaN          NaN         0.0
# 363       NaN      NaN          NaN          NaN          NaN         0.0
# 372       NaN      NaN          NaN          NaN          NaN         0.0
# 393       NaN      NaN          NaN          NaN          NaN         0.0
# ...

# %%
bsmt_num = 0

for feat in num_bsmt_feat:
    df_mvi[feat] = df_mvi[feat].replace(np.nan, bsmt_num)

# %%
df_mvi[num_bsmt_feat].isnull().sum()
# Out:
# BsmtFinSF1      0
# BsmtFinSF2      0
# BsmtUnfSF       0
# TotalBsmtSF     0
# BsmtFullBath    0
# BsmtHalfBath    0
# dtype: int64

# %% [markdown]
# ## Handling Electrical = 0.034258 & KitchenQual = 0.034258

# %%
df["Electrical"].value_counts()
# Out:
# Electrical
# SBrkr    2671
# FuseA     188
# FuseF      50
# FuseP       8
# Mix         1
# Name: count, dtype: int64

# %%
df["KitchenQual"].value_counts()
# Out:
# KitchenQual
# TA    1492
# Gd    1151
# Ex     205
# Fa      70
# Name: count, dtype: int64

# %%
df_ekk = df[["Electrical", "KitchenQual", "KitchenAbvGr"]]
df_ekk[df_ekk.isnull().any(axis=1)]
# Out:
#      Electrical KitchenQual  KitchenAbvGr
# Id
# 1380        NaN          Gd             1
# 1556      SBrkr         NaN             1

# %%
electrical_mode = df_mvi["Electrical"].mode()[0]
df_mvi["Electrical"] = df_mvi["MasVnrType"].fillna(electrical_mode)
print(df_mvi["Electrical"].isnull().sum())
# Out:
# 0

# %%
kitchenqual_mode = df_mvi["KitchenQual"].mode()[0]
df_mvi["KitchenQual"] = df_mvi["KitchenQual"].fillna(kitchenqual_mode)
print(df_mvi["KitchenQual"].isnull().sum())
# Out:
# 0

# %% [markdown]
# # Handling Remaining cat feature

# %% [raw]
# Functional       0.068517 mode
# FireplaceQu     48.646797 NA
#
# PoolQC          99.657417 NA
# Fence           80.438506 NA
# MiscFeature     96.402878 NA
# SaleType         0.034258 mode

# %%
  df["Functional"].value_counts()
# Out:
# Functional
# Typ     2717
# Min2      70
# Min1      65
# Mod       35
# Maj1      19
# Maj2       9
# Sev        2
# Name: count, dtype: int64

# %%
functional_mode = df_mvi["Functional"].mode()[0]
df_mvi["Functional"] = df_mvi["Functional"].fillna(functional_mode)
print(df_mvi["Functional"].isnull().sum())
# Out:
# 0

# %%
  df["SaleType"].value_counts()
# Out:
# SaleType
# WD       2525
# New       239
# COD        87
# ConLD      26
# CWD        12
# ConLI       9
# ConLw       8
# Oth         7
# Con         5
# Name: count, dtype: int64

# %%
saletype_mode = df["SaleType"].mode()[0]
df_mvi["SaleType"] = df_mvi["SaleType"].fillna(saletype_mode)
print(df_mvi["SaleType"].isnull().sum())
# Out:
# 0

# %%
other_cat_feat = ["FireplaceQu",     
"PoolQC",         
"Fence",           
"MiscFeature"]    

for feat in other_cat_feat:
   print(f"Value count of {feat}: {df[feat].value_counts()}")
# Out:
# Value count of FireplaceQu: FireplaceQu
# Gd    744
# TA    592
# Fa     74
# Po     46
# Ex     43
# Name: count, dtype: int64
# Value count of PoolQC: PoolQC
# Ex    4
# Gd    4
# Fa    2
# Name: count, dtype: int64
# Value count of Fence: Fence
# MnPrv    329
# GdPrv    118
# GdWo     112
# MnWw      12
# Name: count, dtype: int64
# Value count of MiscFeature: MiscFeature
# Shed    95
# Gar2     5
# Othr     4
# TenC     1
# Name: count, dtype: int64

# %%
fireplacequ_mode = "NA"
df_mvi["FireplaceQu"] = df_mvi["FireplaceQu"].fillna(fireplacequ_mode)
print(df_mvi["FireplaceQu"].isnull().sum())
# Out:
# 0

# %%
fence_mode = "NA"
df_mvi["Fence"] = df_mvi["Fence"].fillna(fence_mode)
print(df_mvi["Fence"].isnull().sum())
# Out:
# 0

# %%
miscfeature_mode = "NA"
df_mvi["MiscFeature"] = df_mvi["MiscFeature"].fillna(miscfeature_mode)
print(df_mvi["MiscFeature"].isnull().sum())
# Out:
# 0

# %% [markdown]
# ## Handling Garage Feature

# %% [raw]
# GarageType       5.378554 NA
# GarageFinish     5.447071 NA
# GarageQual       5.447071 NA
# GarageCond       5.447071 NA
#
# GarageYrBlt      5.447071 0
# GarageCars       0.034258 0
# GarageArea       0.034258 0

# %%
cat_garage_feat = ["GarageType", "GarageFinish", "GarageQual", "GarageCond"]
num_garage_feat = ["GarageYrBlt", "GarageCars","GarageArea"]

df_garage = df[num_garage_feat+cat_garage_feat]
df_garage[df_garage .isnull().any(axis=1)]
# Out:
#       GarageYrBlt  GarageCars  GarageArea GarageType GarageFinish GarageQual  \
# Id
# 40            NaN         0.0         0.0        NaN          NaN        NaN
# 49            NaN         0.0         0.0        NaN          NaN        NaN
# 79            NaN         0.0         0.0        NaN          NaN        NaN
# 89            NaN         0.0         0.0        NaN          NaN        NaN
# 90            NaN         0.0         0.0        NaN          NaN        NaN
# 100           NaN         0.0         0.0        NaN          NaN        NaN
# 109           NaN         0.0         0.0        NaN          NaN        NaN
# 126           NaN         0.0         0.0        NaN          NaN        NaN
# 128           NaN         0.0         0.0        NaN          NaN        NaN
# 141           NaN         0.0         0.0        NaN          NaN        NaN
# 149           NaN         0.0         0.0        NaN          NaN        NaN
# ...

# %%
garage_cont = "NA"

for feat in cat_garage_feat:
    df_mvi[feat] = df_mvi[feat].replace(np.nan, garage_cont)
    
df_mvi[cat_garage_feat].isnull().sum()
# Out:
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# dtype: int64

# %%
garage_num = 0

for feat in num_garage_feat:
    df_mvi[feat] = df_mvi[feat].replace(np.nan, garage_num)
    
df_mvi[num_garage_feat].isnull().sum()
# Out:
# GarageYrBlt    0
# GarageCars     0
# GarageArea     0
# dtype: int64

# %%
df_mvi.isnull().any(axis=1).sum().item()
# Out:
# 2912

# %% [markdown]
# ## Feature Transformation
# ## Conver Numerical Feature To Categorical Feature

# %%
for_num_conv = ["MSSubClass", "YearBuilt", "YearRemodAdd", "GarageYrBlt", "MoSold", "YrSold"]

for feat in for_num_conv:
    print(f"{feat}: data type = {df_mvi[feat].dtype}")
# Out:
# MSSubClass: data type = int64
# YearBuilt: data type = int64
# YearRemodAdd: data type = int64
# GarageYrBlt: data type = float64
# MoSold: data type = int64
# YrSold: data type = int64

# %%
df_mvi[for_num_conv].head()
# Out:
#     MSSubClass  YearBuilt  YearRemodAdd  GarageYrBlt  MoSold  YrSold
# Id
# 1           60       2003          2003       2003.0       2    2008
# 2           20       1976          1976       1976.0       5    2007
# 3           60       2001          2002       2001.0       9    2008
# 4           70       1915          1970       1998.0       2    2006
# 5           60       2000          2000       2000.0      12    2008

# %%
df_mvi["MoSold"].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6])

# %%
df_mvi["MoSold"] = df_mvi["MoSold"].apply(lambda x: calendar.month_abbr[int(x)] if pd.notna(x) else x)

df_mvi["MoSold"].unique()
# Out:
# array(['Feb', 'May', 'Sep', 'Dec', 'Oct', 'Aug', 'Nov', 'Apr', 'Jan',
#        'Jul', 'Mar', 'Jun'], dtype=object)

# %%
for feat in for_num_conv:
    df_mvi[feat] = df_mvi[feat].astype(str)

# %%
for feat in for_num_conv:
    print(f"{feat}: data type = {df_mvi[feat].dtype}")
# Out:
# MSSubClass: data type = object
# YearBuilt: data type = object
# YearRemodAdd: data type = object
# GarageYrBlt: data type = object
# MoSold: data type = object
# YrSold: data type = object

# %% [markdown]
# ## Convert Categorical Features into Numerical Features
# ### Ordinal Enconding

# %%
ordinal_end_var = [
"ExterQual",
"ExterCond",
"BsmtQual",
"BsmtCond",
"BsmtExposure",
"BsmtFinType1",
"BsmtFinSF1",
"BsmtFinType2",
"HeatingQC",
"KitchenQual",
"FireplaceQu",
"GarageQual",
"GarageCond",
"PoolQc",
"Functional",
"GarageFinish",
"PavedDrive",
"Utilities"
]

print("Total number of features to convert ordinal numerical formate:", len(ordinal_end_var))
# Out:
# Total number of features to convert ordinal numerical formate: 18

# %%
df_mvi["ExterQual"].value_counts()
# Out:
# ExterQual
# TA    1798
# Gd     979
# Ex     107
# Fa      35
# Name: count, dtype: int64

# %%
df_mvi["ExterQual"].unique()
# Out:
# array(['Gd', 'TA', 'Ex', 'Fa'], dtype=object)

# %%
df_mvi["ExterQual"] = df_mvi["ExterQual"].astype(CategoricalDtype(categories=["Po", "Fa", "TA", "Gd", "Ex"],ordered=True)).cat.codes

# %%
df_mvi["ExterQual"].unique()
# Out:
# array([3, 2, 4, 1], dtype=int8)

# %%
df_mvi["ExterQual"].value_counts()
# Out:
# ExterQual
# 2    1798
# 3     979
# 4     107
# 1      35
# Name: count, dtype: int64

# %%
df_mvi["BsmtExposure"].unique()
# Out:
# array(['No', 'Gd', 'Mn', 'Av', 'NA'], dtype=object)

# %%
df_mvi["BsmtExposure"].value_counts()
# Out:
# BsmtExposure
# No    1904
# Av     418
# Gd     276
# Mn     239
# NA      82
# Name: count, dtype: int64

# %%
df_mvi["BsmtExposure"] = df_mvi["BsmtExposure"].astype(CategoricalDtype(categories=["NA", "No", "Mn", "Av", "Gd"],ordered=True)).cat.codes

# %%
df_mvi["BsmtExposure"].unique()
# Out:
# array([1, 4, 2, 3, 0], dtype=int8)

# %%
df_mvi["BsmtExposure"].value_counts()
# Out:
# BsmtExposure
# 1    1904
# 3     418
# 4     276
# 2     239
# 0      82
# Name: count, dtype: int64

# %% [raw]
# "ExterCond"
# "BsmtQual"
# "BsmtCond"
# "BsmtFinType1"
# "BsmtFinSF1"
# "BsmtFinType2"
# "HeatingQC"
# "KitchenQual"
# "FireplaceQu"
# "GarageQual"
# "GarageCond"
# "PoolQc"
# "Functional"
# "GarageFinish"
# "PavedDrive"
# "Utilities"

# %%
df_mvi["ExterCond"] = df_mvi["ExterCond"].astype(CategoricalDtype(categories=["Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["BsmtQual"] = df_mvi["BsmtQual"].astype(CategoricalDtype(categories=["NA", "Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["BsmtCond"] = df_mvi["BsmtCond"].astype(CategoricalDtype(categories=["NA", "Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["BsmtFinType1"] = df_mvi["BsmtFinType1"].astype(CategoricalDtype(categories=["NA", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"], ordered=True)).cat.codes

df_mvi["BsmtFinType2"] = df_mvi["BsmtFinType2"].astype(CategoricalDtype(categories=["NA", "Unf", "LwQ", "Rec", "BLQ", "ALQ", "GLQ"], ordered=True)).cat.codes

df_mvi["HeatingQC"] = df_mvi["HeatingQC"].astype(CategoricalDtype(categories=["Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["KitchenQual"] = df_mvi["KitchenQual"].astype(CategoricalDtype(categories=["Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["FireplaceQu"] = df_mvi["FireplaceQu"].astype(CategoricalDtype(categories=["NA", "Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["GarageQual"] = df_mvi["GarageQual"].astype(CategoricalDtype(categories=["NA", "Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["GarageCond"] = df_mvi["GarageCond"].astype(CategoricalDtype(categories=["NA", "Po", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["PoolQC"] = df_mvi["PoolQC"].astype(CategoricalDtype(categories=["NA", "Fa", "TA", "Gd", "Ex"], ordered=True)).cat.codes

df_mvi["Functional"] = df_mvi["Functional"].astype(CategoricalDtype(categories=["Sal", "Sev", "Maj2", "Maj1", "Mod", "Min2", "Min1", "Typ"],ordered=True)).cat.codes

df_mvi["GarageFinish"] = df_mvi["GarageFinish"].astype(CategoricalDtype(categories=["NA", "Unf", "RFn", "Fin"], ordered=True)).cat.codes

df_mvi["PavedDrive"] = df_mvi["PavedDrive"].astype(CategoricalDtype(categories=["N", "P", "Y"], ordered=True)).cat.codes

df_mvi["Utilities"] = df_mvi["Utilities"].astype(CategoricalDtype(categories=["ELO", "NoSeWa", "NoSewr", "AllPub"], ordered=True)).cat.codes

# %%
df_mvi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2919 entries, 1 to 2919
# Data columns (total 80 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSSubClass     2919 non-null   object
#  1   MSZoning       2919 non-null   object
#  2   LotFrontage    2919 non-null   float64
#  3   LotArea        2919 non-null   int64
#  4   Street         2919 non-null   object
#  5   Alley          2919 non-null   object
#  6   LotShape       2919 non-null   object
#  7   LandContour    2919 non-null   object
#  8   Utilities      2919 non-null   int8
#  9   LotConfig      2919 non-null   object
#  10  LandSlope      2919 non-null   object
#  11  Neighborhood   2919 non-null   object
#  12  Condition1     2919 non-null   object
#  13  Condition2     2919 non-null   object
#  14  BldgType       2919 non-null   object
#  15  HouseStyle     2919 non-null   object
#  16  OverallQual    2919 non-null   int64
# ...

# %% [markdown]
# ## One Hot Encoding for Nominal Categorical Data

# %%
df_encod = df_mvi.copy()

object_features = df_encod.select_dtypes(include="object").columns.tolist()
print("Total object data type features :",len(object_features ))

print("Features: \n ", object_features)
# Out:
# Total object data type features : 32
# Features:
#   ['MSSubClass', 'MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'YearBuilt', 'YearRemodAdd', 'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'Foundation', 'Heating', 'CentralAir', 'Electrical', 'GarageType', 'GarageYrBlt', 'Fence', 'MiscFeature', 'MoSold', 'YrSold', 'SaleType', 'SaleCondition']

# %%
df_encod[object_features].head(2)
# Out:
#    MSSubClass MSZoning Street Alley LotShape LandContour LotConfig LandSlope  \
# Id
# 1          60       RL   Pave    NA      Reg         Lvl    Inside       Gtl
# 2          20       RL   Pave    NA      Reg         Lvl       FR2       Gtl
#
#    Neighborhood Condition1 Condition2 BldgType HouseStyle YearBuilt  \
# Id
# 1       CollgCr       Norm       Norm     1Fam     2Story      2003
# 2       Veenker      Feedr       Norm     1Fam     1Story      1976
#
#    YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1          2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2          1976     Gable  CompShg     MetalSd     MetalSd    BrkFace
#
#    Foundation Heating CentralAir Electrical GarageType GarageYrBlt Fence  \
# Id
# 1       PConc    GasA          Y    BrkFace     Attchd      2003.0    NA
# 2      CBlock    GasA          Y    BrkFace     Attchd      1976.0    NA
#
#    MiscFeature MoSold YrSold SaleType SaleCondition
# Id
# ...

# %%
print("Shape of DF before encoding:", df_encod.shape)

df_encod = pd.get_dummies(
    df_encod,
    columns=object_features,
    prefix=object_features,
    drop_first=True,
    dtype=int
)

print("Shape of DF after encoding:", df_encod.shape)
# Out:
# Shape of DF before encoding: (2919, 80)
# Shape of DF after encoding: (2919, 510)

# %%
df_encod.head(2)
# Out:
#     LotFrontage  LotArea  Utilities  OverallQual  OverallCond  MasVnrArea  \
# Id
# 1          65.0     8450          3            7            5       196.0
# 2          80.0     9600          3            6            8         0.0
#
#     ExterQual  ExterCond  BsmtQual  BsmtCond  BsmtExposure  BsmtFinType1  \
# Id
# 1           3          2         4         3             1             6
# 2           2          2         4         3             4             5
#
#     BsmtFinSF1  BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  HeatingQC  \
# Id
# 1        706.0             1         0.0      150.0        856.0          4
# 2        978.0             1         0.0      284.0       1262.0          4
#
#     1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1        856       854             0       1710           1.0           0.0
# 2       1262         0             0       1262           0.0           1.0
#
# ...

# %%
df_encod.select_dtypes(include="object").columns.tolist()
# Out:
# []

# %% [markdown]
# ## Split Data for Training & Testing

# %%
 df_encod.shape
# Out:
# (2919, 510)

# %%
len_train = df_train.shape[0]
len_train
# Out:
# 1460

# %%
x_train =  df_encod[:len_train].drop("SalePrice",axis=1)
y_train =  df_encod["SalePrice"][:len_train]

x_test =  df_encod[len_train:].drop("SalePrice",axis=1)

print("Shape of X_train data :", x_train.shape)
print("Shape of Y_train data :", y_train.shape)
print("Shape of X_testdata :", x_test.shape)
# Out:
# Shape of X_train data : (1460, 509)
# Shape of Y_train data : (1460,)
# Shape of X_testdata : (1459, 509)

# %% [markdown]
# ## Feature Scaling

# %%
sc = StandardScaler()
sc.fit(x_train)

# Formula z = (x-u)/s

x_train = sc.transform(x_train)
x_test = sc.transform(x_test)

# %%
x_train[:3,:]
# Out:
# array([[-0.22335706, -0.20714171,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [ 0.45789401, -0.09188637,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [-0.08710685,  0.07347998,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503]], shape=(3, 509))

# %%
x_test[:3,:]
# Out:
# array([[ 0.45789401,  0.11076257,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [ 0.50331075,  0.37584985,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503],
#        [ 0.18539358,  0.33205282,  0.02618016, ..., -0.11785113,
#          0.4676514 , -0.30599503]], shape=(3, 509))

# %% [markdown]
# ## Carry Forward For Deployment

# %%
#sc.mean_
#sc.n_features_in_
#sc.n_samples_seen_
#sc.scale_
#sc.var_
#sc.with_mean
#sc.with_s

# %% [markdown]
# ## Train ML Model

# %%
# !pip install xgboost

# %%
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression, SGDRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.gaussian_process import GaussianProcessRegressor
from sklearn.tree import DecisionTreeRegressor

from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor

from sklearn.isotonic import IsotonicRegression

from sklearn.neural_network import MLPRegressor

from xgboost import XGBRegressor

# %%
svr = SVR()
lr = LinearRegression()
sgdr = SGDRegressor()
knr = KNeighborsRegressor()
gpr = GaussianProcessRegressor()
dtr = DecisionTreeRegressor()
gbr = GradientBoostingRegressor()
rfr = RandomForestRegressor()
xgbr = XGBRegressor()

mlpr = MLPRegressor()
ir = IsotonicRegression()

# %%
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import make_scorer, r2_score

def test_model(model, x_train=x_train, y_train=y_train):
    cv = KFold(n_splits = 7, shuffle=True, random_state = 45)
    r2 = make_scorer(r2_score)
    r2_val_score = cross_val_score(model, x_train, y_train, cv=cv, scoring = r2)
    score = [r2_val_score.mean()]
    return score

# %%
models = {"a":["LinearRegression", lr],
        "b":["SVR", svr],
        "c":["SGDRegressor", sgdr],
        "d":["KNeighborsRegressor", knr],
        "e":["GaussianProcessRegressor", gpr],
        "f":["DecisionTreeRegressor", dtr],
        "g":["GradientBoostingRegressor", gbr],
        "h":["RandomForestRegressor", rfr],
        "i":["XGBRegressor", xgbr],
        "j": ["MLPRegressor", mlpr],
        "k": ["IsotonicRegression", ir]
        }

# %%
models_score = []

for model in models:
    print("Training model : ", models[model][0])
    score = test_model(models[model] [1], x_train, y_train)
    print("Score of model : ", score)
    models_score.append([models [model] [0], score[0]])
# Out:
# Training model :  LinearRegression
# Score of model :  [np.float64(0.5015224913790479)]
# Training model :  SVR
# Score of model :  [np.float64(-0.05214508340793004)]
# Training model :  SGDRegressor
# Score of model :  [np.float64(-940.6185459013425)]
# Training model :  KNeighborsRegressor
# Score of model :  [np.float64(0.5506506652308846)]
# Training model :  GaussianProcessRegressor
# Score of model :  [np.float64(-5.398916233751846)]
# Training model :  DecisionTreeRegressor
# Score of model :  [np.float64(0.6852030943712982)]
# Training model :  GradientBoostingRegressor
# Score of model :  [np.float64(0.8707056679450795)]
# Training model :  RandomForestRegressor
# Score of model :  [np.float64(0.843503449264455)]
# Training model :  XGBRegressor
# Score of model :  [np.float64(0.846551628654134)]
# Training model :  MLPRegressor
# ...

# %% [markdown]
# ## 5-Fold Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

gbr = GradientBoostingRegressor(random_state=42)

scores = cross_val_score(
    gbr,
    x_train,
    y_train,
    cv=5,
    scoring="r2"
)

print("CV Scores :", scores)
print("Mean CV Score:", scores.mean())
print("Standard Deviation:", scores.std())
# Out:
# CV Scores : [0.90171875 0.84974616 0.88921559 0.891866   0.90543313]
# Mean CV Score: 0.887595926669773
# Standard Deviation: 0.019854880945529594

# %% [markdown]
# ## Hyperparameter Tuning using GridSearchCV

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import GridSearchCV

gbr = GradientBoostingRegressor(random_state=42)

param_grid = {
    "n_estimators": [100, 200],
    "learning_rate": [0.05, 0.1],
    "max_depth": [2, 3, 4],
    "min_samples_split": [2, 5]
}

grid_search = GridSearchCV(
    estimator=gbr,
    param_grid=param_grid,
    cv=5,
    scoring="r2",
    n_jobs=-1
)

grid_search.fit(x_train, y_train)

print("Best Parameters:")
print(grid_search.best_params_)

print("Best CV Score:")
print(grid_search.best_score_)
# Out:
# Best Parameters:
# {'learning_rate': 0.1, 'max_depth': 2, 'min_samples_split': 5, 'n_estimators': 200}
# Best CV Score:
# 0.8921913422737522

# %%
best_model = grid_search.best_estimator_

# %% [markdown]
# ## Selecting The Best Model

# %%
best_model = grid_search.best_estimator_

print(best_model)
# Out:
# GradientBoostingRegressor(max_depth=2, min_samples_split=5, n_estimators=200,
#                           random_state=42)

# %% [markdown]
# ## Saving The Trained Model

# %%
import joblib

joblib.dump(best_model, "house_price_model.pkl")
# Out:
# ['house_price_model.pkl']

# %%
import os

print(os.path.exists("house_price_model.pkl"))
# Out:
# True

# %%
import joblib

model = joblib.load("house_price_model.pkl")

print(model)
# Out:
# GradientBoostingRegressor(max_depth=2, min_samples_split=5, n_estimators=200,
#                           random_state=42)

# %%
y_pred = model.predict(x_test)

print(y_pred[:10])
# Out:
# [116519.66956817 168195.17929285 180210.76182427 184864.43338135
#  207900.41797905 165792.79021088 158604.89607539 157903.52022983
#  194799.14896895 128696.34546653]

# %%
print("Number of predictions:", len(y_pred))
# Out:
# Number of predictions: 1459

# %%
print("Minimum predicted price:", y_pred.min())
print("Maximum predicted price:", y_pred.max())
# Out:
# Minimum predicted price: 50314.98632979903
# Maximum predicted price: 629426.3443627392

# %%
print(df_mvi.columns[:10])
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig'],
#       dtype='object')

# %%
print("Id" in df_mvi.columns)
# Out:
# False

# %%
# %whos
# Out:
# Variable                    Type                         Data/Info
# ------------------------------------------------------------------
# CategoricalDtype            type                         <class 'pandas.core.dtype<...>dtypes.CategoricalDtype'>
# DecisionTreeRegressor       ABCMeta                      <class 'sklearn.tree._cla<...>s.DecisionTreeRegressor'>
# GaussianProcessRegressor    type                         <class 'sklearn.gaussian_<...>aussianProcessRegressor'>
# GradientBoostingRegressor   ABCMeta                      <class 'sklearn.ensemble.<...>adientBoostingRegressor'>
# GridSearchCV                ABCMeta                      <class 'sklearn.model_sel<...>on._search.GridSearchCV'>
# IsotonicRegression          type                         <class 'sklearn.isotonic.IsotonicRegression'>
# KFold                       ABCMeta                      <class 'sklearn.model_selection._split.KFold'>
# ...

# %% [markdown]
# ## Test Prediction

# %%
print(y_pred[:10])
# Out:
# [116519.66956817 168195.17929285 180210.76182427 184864.43338135
#  207900.41797905 165792.79021088 158604.89607539 157903.52022983
#  194799.14896895 128696.34546653]

# %% [markdown]
# ## Submission CSV

# %%
submission = pd.DataFrame({
    "Id": df_test["Id"],
    "SalePrice": y_pred
})

print(submission.head())
# Out:
#      Id      SalePrice
# 0  1461  116519.669568
# 1  1462  168195.179293
# 2  1463  180210.761824
# 3  1464  184864.433381
# 4  1465  207900.417979

# %%
print(submission.shape)
# Out:
# (1459, 2)

# %%
submission.to_csv("submission.csv", index=False)

# %%
print(os.path.exists("submission.csv"))
# Out:
# True

# %%
feature_names = df_encod.drop("SalePrice", axis=1).columns.tolist()

print("Number of feature names:", len(feature_names))
# Out:
# Number of feature names: 509

# %%
joblib.dump(feature_names, "feature_names.pkl")
# Out:
# ['feature_names.pkl']

# %%
joblib.dump(best_model, "house_price_model.pkl")
# Out:
# ['house_price_model.pkl']

# %%
print(os.path.exists("feature_names.pkl"))
print(os.path.exists("house_price_model.pkl"))
# Out:
# True
# True

# %% [markdown]
# ## Model Reloading & Testing

# %%
model_loaded = joblib.load("house_price_model.pkl")
features_loaded = joblib.load("feature_names.pkl")

print(type(model_loaded))
print(len(features_loaded))
# Out:
# <class 'sklearn.ensemble._gb.GradientBoostingRegressor'>
# 509

# %%
y_pred_check = model_loaded.predict(x_test)

print(y_pred_check[:5])
print(y_pred_check.shape)
# Out:
# [116519.66956817 168195.17929285 180210.76182427 184864.43338135
#  207900.41797905]
# (1459,)

# %% [markdown]
# ## Streamlit install

# %%
# !pip install streamlit

# %%
import streamlit
print(streamlit.__version__)
# Out:
# 1.51.0
